# %% [markdown]
# # 13. 함수적용
# ---
# - pandas에서 데이터 변형을 수행할 때, apply()함수는 강력한 도구이다.
# - 이함수를 사용하면 DataFrame 또는 Series의 각 요소에 대해 원하는 연산을 수행 할 수 있다.

# %%
import pandas as pd
df = pd.read_csv('data/customers3.csv', index_col='고객ID')
df
# Out:
#       고객명  나이 거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 고객ID
# C001  박태근  35   시흥  Electronics         75         70        78        92
# C002  이영희  30   안양      fashion         85         92        88        85
# C003  박지성  35   울산          NaN         95        110        91        88
# C004  최민아  40   창원      Fashion         92        105        82        96
# C005  정수빈  28   구로      Fashion         82         88        94        79
# C006  윤태영  27   시흥  Electronics         88         95        85        91
# C007  한유진  31   파주          NaN         68         65        77        83
# C008  강민호  29   일산       Sports         98        125        96        90

# %%
df['최근1년 방문빈도'] = df['고객']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '고객'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['최근1년 방문빈도'] = df['고객']
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '고객'

# %% [markdown]
# **데이터에 함수 적용 `apply()`**
# - DataFrame이나 Series의 각 요소에 함수를 적용할 때 사용된다.
# - 특히 열(Column) 단위나 행(row) 단위로 복잡한 연산을 적용할 때 유용하다.

# %%
def add_keyward(count):
    return str(count) + '회'

# %%
add_keyward(5)
# Out:
# '5회'

# %%
df['최근1년_방문빈도'] = df['최근1년_방문빈도'].apply(add_keyward)
df
# Out:
#       고객명  나이 거주도시        주요관심사 최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 고객ID
# C001  박태근  35   시흥  Electronics       75회         70        78        92
# C002  이영희  30   안양      fashion       85회         92        88        85
# C003  박지성  35   울산          NaN       95회        110        91        88
# C004  최민아  40   창원      Fashion       92회        105        82        96
# C005  정수빈  28   구로      Fashion       82회         88        94        79
# C006  윤태영  27   시흥  Electronics       88회         95        85        91
# C007  한유진  31   파주          NaN       68회         65        77        83
# C008  강민호  29   일산       Sports       98회        125        96        90

# %%
# 첫번째 문자가 대문자인지 아닌지 대문자가 아니면 대문자로 변환

def capitalize(interest):
    # notnull() : NaN인지 아닌지 NaN 이면 False 아니면 True
    if pd.notnull(interest):
        return interest.capitalize()
    return interest

# %%
df['주요관심사'] = df['주요관심사'].apply(capitalize)
df
# Out:
#       고객명  나이 거주도시        주요관심사 최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 고객ID
# C001  박태근  35   시흥  Electronics       75회         70        78        92
# C002  이영희  30   안양      Fashion       85회         92        88        85
# C003  박지성  35   울산          NaN       95회        110        91        88
# C004  최민아  40   창원      Fashion       92회        105        82        96
# C005  정수빈  28   구로      Fashion       82회         88        94        79
# C006  윤태영  27   시흥  Electronics       88회         95        85        91
# C007  한유진  31   파주          NaN       68회         65        77        83
# C008  강민호  29   일산       Sports       98회        125        96        90

# %% [markdown]
# **`merge()`**
# - SQL의 JOIN과 유사하게 두개의 DataFrame을 특정 열을 기준으로 결합한다.

# %%
df1 = pd.DataFrame(
    {
        'CustomerID' : [1,2,3],
        'Product' : ['Laptop', 'Mouse', 'Keyboard']
    }

)


df
# Out:
#       고객명  나이 거주도시        주요관심사 최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 고객ID
# C001  박태근  35   시흥  Electronics       75회         70        78        92
# C002  이영희  30   안양      Fashion       85회         92        88        85
# C003  박지성  35   울산          NaN       95회        110        91        88
# C004  최민아  40   창원      Fashion       92회        105        82        96
# C005  정수빈  28   구로      Fashion       82회         88        94        79
# C006  윤태영  27   시흥  Electronics       88회         95        85        91
# C007  한유진  31   파주          NaN       68회         65        77        83
# C008  강민호  29   일산       Sports       98회        125        96        90

# %%
df1 = pd.DataFrame(
    {
        'CustomerID' : [2,3,4],
        'Product' : ['USA', 'Canada', 'Korea']
    }

)

# %%
df.merge = pd.merge(df1, df2, on = 'CustomerID')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.merge = pd.merge(df1, df2, on = 'CustomerID')
#
# NameError: name 'df2' is not defined

# %% [markdown]
# **`concat()`**
# - DataFrame을 위아래또는 좌, 우로 결합할때 사용한다.
# - 행을 추가할때는 `axis=0`, 열을추가할땐는 `axis=1`을 사용한다.

# %% [markdown]
# **`join()`**
# - 두개의 DataFrame을 인덱스를 기준으로 결합 할 때 사용한다.
